# %% [markdown]
# <a href="https://colab.research.google.com/github/njorogeinc/data_science/blob/main/Recomender_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file = "/content/drive/My Drive/data/data.zip"
from zipfile import ZipFile
with ZipFile(file, 'r') as zip:
  zip.printdir()
  print("Extracting file")
  zip.extractall()
# Out:
# File Name                                             Modified             Size
# genome_scores.csv                              2019-09-20 00:37:06    214322450
# genome_tags.csv                                2019-09-20 00:37:26        20363
# link.csv                                       2019-09-20 00:37:26       539334
# movie.csv                                      2019-09-20 00:37:26      1493648
# rating.csv                                     2019-09-20 00:37:26    690353377
# tag.csv                                        2019-09-20 00:38:24     21725514
# Extracting file

# %%
import glob
import os
import sys
# %pwd
# Out:
# '/content'

# %%
import pandas as pd
sf = pd.read_csv("/content/genome_tags.csv")
sf.head()
# Out:
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
# 3      4         1920s
# 4      5         1930s

# %%
tf = pd.read_csv("/content/tag.csv")
tf.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
rf = pd.read_csv("/content/rating.csv")
rf.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
n_ratings = len(rf)
n_ratings
# Out:
# 20000263

# %%
rf.shape
# Out:
# (20000263, 4)

# %%
n_users = rf['userId']
n_users
# Out:
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
#              ...
# 20000258    138493
# 20000259    138493
# 20000260    138493
# 20000261    138493
# 20000262    138493
# Name: userId, Length: 20000263, dtype: int64

# %%
n_users = rf.userId.unique()
n_users
# Out:
# array([     1,      2,      3, ..., 138491, 138492, 138493])

# %%
n_users = len(rf.userId.unique())
n_users
# Out:
# 138493

# %%
lf = pd.read_csv("/content/link.csv")
lf.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
mf = pd.read_csv("/content/movie.csv")
mf.head()
# Out:
#    movieId  ...                                       genres
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
movie_names = mf.set_index('movieId')

# %%
movie_names.head()
# Out:
#                                       title                                       genres
# movieId
# 1                          Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2                            Jumanji (1995)                   Adventure|Children|Fantasy
# 3                   Grumpier Old Men (1995)                               Comedy|Romance
# 4                  Waiting to Exhale (1995)                         Comedy|Drama|Romance
# 5        Father of the Bride Part II (1995)                                       Comedy

# %%
movie_names = mf.set_index('movieId')['title']
movie_names.head()
# Out:
# movieId
# 1                      Toy Story (1995)
# 2                        Jumanji (1995)
# 3               Grumpier Old Men (1995)
# 4              Waiting to Exhale (1995)
# 5    Father of the Bride Part II (1995)
# Name: title, dtype: object

# %%
movie_names = mf.set_index('movieId')['title'].to_dict()
movie_names
# Out:
# {1: 'Toy Story (1995)',
#  2: 'Jumanji (1995)',
#  3: 'Grumpier Old Men (1995)',
#  4: 'Waiting to Exhale (1995)',
#  5: 'Father of the Bride Part II (1995)',
#  6: 'Heat (1995)',
#  7: 'Sabrina (1995)',
#  8: 'Tom and Huck (1995)',
#  9: 'Sudden Death (1995)',
#  10: 'GoldenEye (1995)',
#  11: 'American President, The (1995)',
#  12: 'Dracula: Dead and Loving It (1995)',
#  13: 'Balto (1995)',
#  14: 'Nixon (1995)',
#  15: 'Cutthroat Island (1995)',
#  16: 'Casino (1995)',
#  17: 'Sense and Sensibility (1995)',
#  18: 'Four Rooms (1995)',
#  19: 'Ace Ventura: When Nature Calls (1995)',
#  20: 'Money Train (1995)',
#  21: 'Get Shorty (1995)',
#  22: 'Copycat (1995)',
#  23: 'Assassins (1995)',
#  24: 'Powder (1995)',
#  25: 'Leaving Las Vegas (1995)',
#  26: 'Othello (1995)',
#  27: 'Now and Then (1995)',
#  28: 'Persuasion (1995)',
#  29: 'City of Lost Children, The (Cité des enfants perdus, La) (1995)',
#  30: 'Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)',
# ...

# %%
n_movies = len(mf.movieId.unique())
n_movies
# Out:
# 27278

# %%
 matris = (n_ratings) / (n_users * n_movies) * 100 
 matris
# Out:
# 0.5294139230357806

# %%
z = pd.read_csv("/content/genome_scores.csv")
z.head()
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02500
# 1        1      2    0.02500
# 2        1      3    0.05775
# 3        1      4    0.09675
# 4        1      5    0.14675

# %%
cm = []

a = %pwd
hf = glob.glob(a + "/*.csv")

for i in hf:
  cm.append(pd.read_csv(i))

# %%
big_frame = pd.concat(cm, ignore_index=True)

# %%
big_frame.head()
# Out:
#    movieId  tagId  relevance  tag  ...  title  genres imdbId tmdbId
# 0      1.0    1.0    0.02500  NaN  ...    NaN     NaN    NaN    NaN
# 1      1.0    2.0    0.02500  NaN  ...    NaN     NaN    NaN    NaN
# 2      1.0    3.0    0.05775  NaN  ...    NaN     NaN    NaN    NaN
# 3      1.0    4.0    0.09675  NaN  ...    NaN     NaN    NaN    NaN
# 4      1.0    5.0    0.14675  NaN  ...    NaN     NaN    NaN    NaN
#
# [5 rows x 11 columns]

# %%
big_frame.describe
# Out:
# <bound method NDFrame.describe of            movieId  tagId  relevance  tag  ...  title  genres     imdbId    tmdbId
# 0              1.0    1.0    0.02500  NaN  ...    NaN     NaN        NaN       NaN
# 1              1.0    2.0    0.02500  NaN  ...    NaN     NaN        NaN       NaN
# 2              1.0    3.0    0.05775  NaN  ...    NaN     NaN        NaN       NaN
# 3              1.0    4.0    0.09675  NaN  ...    NaN     NaN        NaN       NaN
# 4              1.0    5.0    0.14675  NaN  ...    NaN     NaN        NaN       NaN
# ...            ...    ...        ...  ...  ...    ...     ...        ...       ...
# 32231274  131254.0    NaN        NaN  NaN  ...    NaN     NaN   466713.0    4436.0
# 32231275  131256.0    NaN        NaN  NaN  ...    NaN     NaN   277703.0    9274.0
# 32231276  131258.0    NaN        NaN  NaN  ...    NaN     NaN  3485166.0  285213.0
# 32231277  131260.0    NaN        NaN  NaN  ...    NaN     NaN   249110.0   32099.0
# ...

# %%
big_frame.info
# Out:
# <bound method DataFrame.info of            movieId  tagId  relevance  tag  ...  title  genres     imdbId    tmdbId
# 0              1.0    1.0    0.02500  NaN  ...    NaN     NaN        NaN       NaN
# 1              1.0    2.0    0.02500  NaN  ...    NaN     NaN        NaN       NaN
# 2              1.0    3.0    0.05775  NaN  ...    NaN     NaN        NaN       NaN
# 3              1.0    4.0    0.09675  NaN  ...    NaN     NaN        NaN       NaN
# 4              1.0    5.0    0.14675  NaN  ...    NaN     NaN        NaN       NaN
# ...            ...    ...        ...  ...  ...    ...     ...        ...       ...
# 32231274  131254.0    NaN        NaN  NaN  ...    NaN     NaN   466713.0    4436.0
# 32231275  131256.0    NaN        NaN  NaN  ...    NaN     NaN   277703.0    9274.0
# 32231276  131258.0    NaN        NaN  NaN  ...    NaN     NaN  3485166.0  285213.0
# 32231277  131260.0    NaN        NaN  NaN  ...    NaN     NaN   249110.0   32099.0
# ...

# %%
big_frame.isna().sum()
# Out:
# movieId          1128
# tagId        20520383
# relevance    20521511
# tag          31764603
# userId       11765452
# rating       12231016
# timestamp    11765452
# title        32204001
# genres       32204001
# imdbId       32204001
# tmdbId       32204253
# dtype: int64

# %%
big_frame.columns
# Out:
# Index(['movieId', 'tagId', 'relevance', 'tag', 'userId', 'rating', 'timestamp',
#        'title', 'genres', 'imdbId', 'tmdbId'],
#       dtype='object')

# %%
big_frame.shape
# Out:
# (32231279, 11)

# %%
big_frame.values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3a869b634bc7> in <module>()
# ----> 1 big_frame.values()
#
# NameError: name 'big_frame' is not defined

# %%
df = big_frame.set_index("movieId", inplace = True)
